# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
client_data = "../data/clean/clean_client_data.csv"
analysis_data = "../data/clean/analysis_data.csv"

# %%
client_df = pd.read_csv(client_data)
analysis_df = pd.read_csv(analysis_data)

# %%
analysis_df.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0        169  201385055_71273495308  749567106_99161211863_557568
# 1        169  201385055_71273495308  749567106_99161211863_557568
# 2        169  201385055_71273495308  749567106_99161211863_557568
# 3        169  201385055_71273495308  749567106_99161211863_557568
# 4        169  201385055_71273495308  749567106_99161211863_557568
#
#   process_step            date_time Variation  visit_final_step  \
# 0        start  2017-04-12 20:19:36       NaN             False
# 1       step_1  2017-04-12 20:19:45       NaN             False
# 2       step_2  2017-04-12 20:20:31       NaN             False
# 3       step_3  2017-04-12 20:22:05       NaN             False
# 4      confirm  2017-04-12 20:23:09       NaN              True
#
#    step_duration  step_proceeds  step_error
# 0            9.0           True       False
# 1           46.0           True       False
# 2           94.0           True       False
# 3           64.0           True       False
# 4            NaN          False       False

# %%
analysis_df.pivot_table(index='process_step',
                        columns='Variation',
                        values=['visit_final_step','step_proceeds','step_error','step_duration'],
                        aggfunc='mean').round(2)
# Out:
#              step_duration         step_error       step_proceeds        \
# Variation          Control    Test    Control  Test       Control  Test
# process_step
# confirm             221.95  192.46       0.00  0.00          0.00  0.00
# start                39.46   32.40       0.00  0.00          0.68  0.71
# step_1               55.39   72.09       0.07  0.13          0.75  0.71
# step_2               94.31   91.99       0.06  0.11          0.82  0.78
# step_3              146.89  165.14       0.10  0.09          0.66  0.70
#
#              visit_final_step
# Variation             Control  Test
# process_step
# confirm                  0.96  0.99
# start                    0.31  0.29
# step_1                   0.12  0.08
# step_2                   0.06  0.04
# step_3                   0.10  0.07

# %%
analysis_df[analysis_df['step_proceeds']==True].pivot_table(index='process_step',
                                                            columns='Variation',
                                                            values=['step_duration'],
                                                            aggfunc='mean').round(2)
# Out:
#              step_duration
# Variation          Control    Test
# process_step
# start                38.02   31.71
# step_1               33.82   37.14
# step_2               87.01   86.51
# step_3              135.80  143.13

# %%
analysis_df[analysis_df['step_proceeds']==True].head()
# Out:
#     index  client_id             visitor_id                      visit_id  \
# 0  374121        169  201385055_71273495308  749567106_99161211863_557568
# 1  374120        169  201385055_71273495308  749567106_99161211863_557568
# 2  374119        169  201385055_71273495308  749567106_99161211863_557568
# 3  374118        169  201385055_71273495308  749567106_99161211863_557568
# 5   94261        555  402506806_56087378777  637149525_38041617439_716659
#
#   process_step            date_time Variation  visit_final_step  \
# 0        start  2017-04-12 20:19:36       NaN             False
# 1       step_1  2017-04-12 20:19:45       NaN             False
# 2       step_2  2017-04-12 20:20:31       NaN             False
# 3       step_3  2017-04-12 20:22:05       NaN             False
# 5        start  2017-04-15 12:57:56      Test             False
#
#    step_duration  step_proceeds  step_error
# 0            9.0           True       False
# 1           46.0           True       False
# 2           94.0           True       False
# 3           64.0           True       False
# 5            7.0           True       False
